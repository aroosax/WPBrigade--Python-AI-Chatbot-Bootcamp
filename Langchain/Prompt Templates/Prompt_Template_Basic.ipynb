# %%
! pip install langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from google.colab import userdata

# %%
api_key = userdata.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash",
    google_api_key = api_key
)

# %% [markdown]
# #**Example 1**

# %%
# Providing a Template
# {tone}, {topic}, and {skill} will be filled in later dynamically
template = (
    "Write a {tone} LinkedIn post about {topic}. " \
    "Highlight {skill} as a key expertise area " \
    "and make it engaging in under 5 lines."
)
#converting the template into a chat prompt template
prompt_template = ChatPromptTemplate.from_template(template)

#filling the template with actual values
prompt = prompt_template.invoke({
    "tone": "professional",
    "topic": "the importance of clean data in analytics",
    "skill": "SQL | Power BI | Data Visualization"
})

# The 'prompt' now contains a ready-to-use LinkedIn post prompt
# Getting response
response = llm.invoke(prompt)
print(response.content)
# Out:
# Garbage in, garbage out! Clean data is the bedrock of impactful analytics. I help businesses unlock true insights with expertise in SQL, Power BI, and data visualization, turning raw data into actionable strategies. #DataAnalytics #PowerBI #SQL #DataVisualization

# %% [markdown]
# # **Example 2**

# %%
# Providing a Template
# {tip_type} and {tip_count} will be filled in later dynamically
messages = [
    ("system", "You are a fitness coach who shares quick {tip_type} tips."),
    ("human", "Give me {tip_count} tips I can use daily.")
]

# Converting the messages into a ChatPromptTemplate
prompt_template = ChatPromptTemplate.from_messages(messages)

# Filling the template with actual values
prompt = prompt_template.invoke({
    "tip_type": "health & wellness",
    "tip_count": 3
})

# The 'prompt' now contains a ready-to-use LinkedIn post prompt
# Getting response
response = llm.invoke(prompt)
print(response.content)
# Out:
# Alright, here are 3 daily tips to boost your health and wellness:
#
# 1.  **Hydrate First Thing:** Start your day with a glass of water before anything else. It helps rehydrate your body after sleep, kickstarts your metabolism, and can improve alertness. Aim for 16-20 ounces!
#
# 2.  **Move for 15 Minutes:** Dedicate just 15 minutes to some form of physical activity. This could be a brisk walk, stretching, dancing to your favorite song, or a quick bodyweight circuit. Consistency is key!
#
# 3.  **Practice Mindful Breathing:** Take a few minutes each day to focus on your breath. Try a simple breathing exercise like box breathing (inhale for 4, hold for 4, exhale for 4, hold for 4, repeat). This can reduce stress and improve focus.

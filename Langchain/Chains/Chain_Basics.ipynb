# %% [markdown]
# # **🔗 Chain in LangChain**
# In LangChain, a chain refers to a sequence of steps or operations that are linked together to complete a task. Think of it as running Step1 → Step2 → Step3 in a connected workflow, instead of just calling the LLM directly. Chains help in building more structured, complex, and scalable applications.

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
! pip install langchain-google-genai

# %%
#importing libraries
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from google.colab import userdata

# %%
#api key
api_key = userdata.get("GOOGLE_API_KEY")

# %%
#model
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash",
    google_api_key = api_key
)

# %%
#providing messages
messages = [
     ("system", "You are a facts expert who knows facts about {animal}."),
     ("human", "Tell me {facts_count} facts.")
]
#converting the messages into a chat prompt template
prompt_template = ChatPromptTemplate.from_messages(messages)

#making a chain
chain = prompt_template | llm | StrOutputParser()

#filling the chain with actual values
response = chain.invoke({
    "animal":"cat",
    "facts_count": 5
})

#getting response
print(response)
# Out:
# Okay, here are 5 facts about cats:
#
# 1.  **Cats have a third eyelid:** Called a nictitating membrane, this eyelid provides extra protection and lubrication for the eye. It's usually only visible when a cat is sleepy or unwell.
#
# 2.  **A cat's nose print is unique, just like a human fingerprint:** No two cats have the same pattern of ridges and bumps on their nose.
#
# 3.  **Cats can make over 100 different vocalizations:** In contrast, dogs can only make about 10.
#
# 4.  **Cats can jump up to six times their height:** This impressive ability is due to their strong leg muscles and flexible spine.
#
# 5.  **Cats have whiskers on the back of their front legs:** These whiskers, called carpal vibrissae, help cats detect prey and navigate in tight spaces.

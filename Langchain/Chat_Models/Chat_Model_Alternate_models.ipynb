# %%
! pip install langchain-google-genai

# %%
# Importing libraries
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from google.colab import userdata

# %%
#api key
API_KEY = userdata.get('GOOGLE_API_KEY')

# %% [markdown]
# # **1. Model (Using Gemini 2.0 Flash)**

# %%
# Choosing the model
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash",
    google_api_key = API_KEY
)

# %%
# Creating the Message and getting Response
messages = [
    SystemMessage("You are a travel planning assistant who gives short and clear suggestions."),
    HumanMessage("What are three must-visit places in Paris?")
]
response = llm.invoke(messages)
print(response.content)
# Out:
# 1.  **Eiffel Tower:** Iconic landmark with breathtaking views.
# 2.  **Louvre Museum:** Home to masterpieces like the Mona Lisa.
# 3.  **Notre-Dame Cathedral:** A historic cathedral with stunning architecture. (Note: Currently undergoing restoration, but still worth seeing from the outside).

# %% [markdown]
# # **2. Model (Using Gemini 1.5 Flash)**

# %%
# Choosing the model
llm1 = ChatGoogleGenerativeAI(
    model = "gemini-1.5-flash",
    google_api_key = API_KEY
)

# %%
# Creating the Message and getting Response
messages = [
    SystemMessage("You are a travel planning assistant who gives short and clear suggestions."),
    HumanMessage("What are three must-visit places in Paris?")
]
response = llm1.invoke(messages)
print(response.content)
# Out:
# 1. Eiffel Tower
# 2. Louvre Museum
# 3. Notre Dame Cathedral

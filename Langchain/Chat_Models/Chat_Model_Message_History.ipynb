# %%
! pip install langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from google.colab import userdata

# %%
api_key = userdata.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    model = 'gemini-2.0-flash',
    google_api_key = api_key
)

# %%
#storing messages
#taking an empty array to store messages
chat_history = []
SysMessage = SystemMessage("You are a helpful AI Assistant.")

#storing system message in chat history
chat_history.append(SysMessage)
print('How can i help you?')

#condition for quit or exit
while True:
  user_input = input("Q:")
  if user_input == "quit" or user_input == "exit":
    break
  chat_history.append(HumanMessage(content=user_input))
  print(f"You {user_input}")

  #getting response for the message
  response = llm.invoke(chat_history)
  result = response.content
  chat_history.append(AIMessage(content=result))
  print(f"AI: {result}")


#print chat history
print("--Message History--")
print(chat_history)
# Out:
# How can i help you?
# Q:where is shibuya?
# You where is shibuya?
# AI: Shibuya is a special ward in **Tokyo, Japan**. It's known as one of Tokyo's most vibrant and trendy districts, famous for its iconic scramble crossing, fashion, nightlife, and youth culture.
# Q:what is korea famous for?
# You what is korea famous for?
# AI: Korea, both South and North, is famous for a variety of things. Here's a breakdown:
#
# **South Korea (Republic of Korea) is particularly known for:**
#
# *   **K-Pop & K-Drama:** Globally popular music and television dramas that have a massive international fanbase. Think BTS, Blackpink, Squid Game, and Crash Landing on You.
# *   **Technology:** Home to major tech companies like Samsung and LG, known for smartphones, electronics, and innovation.
# *   **Beauty & Skincare:** Korean beauty products (K-Beauty) are highly regarded for their quality and innovative ingredients.
# *   **Food:** Korean cuisine is beloved, especially Korean BBQ, kimchi, bibimbap, and street food.
# *   **Automobiles:** Hyundai and Kia are major car manufacturers.
# *   **Fashion:** Known for its trendy and unique fashion scene.
# *   **Cosmetics Surgery:** South Korea is a popular destination for cosmetic surgery.
# *   **History and Culture:** Rich history, including ancient palaces, temples, and traditions.
# *   **Taekwondo:** A Korean martial art that is also an Olympic sport.
# *   **Gaming:** A major player in the video game industry and esports.
#
# **North Korea (Democratic People's Republic of Korea) is mostly known for:**
#
# *   **Isolation:** One of the most isolated countries in the world, with limited access to outside information and strict government control.
# *   **Nuclear Program:** Its controversial nuclear weapons program.
# *   **Military:** A large and heavily militarized society.
# *   **Kim Dynasty:** Ruled by the Kim dynasty (Kim Il-sung, Kim Jong-il, and Kim Jong-un) since its founding.
# *   **Propaganda:** Heavily reliant on propaganda to maintain control and promote its ideology.
# *   **Human Rights Concerns:** Facing significant criticism for its human rights record.
#
# It's important to remember that "Korea" is a peninsula with two distinct countries, each with its own unique characteristics and global standing.
# Q:what is pakistan famous for?
# You what is pakistan famous for?
# AI: Pakistan is famous for a variety of things, including:
#
# *   **Historical Significance:**
#     *   **Indus Valley Civilization:** One of the oldest civilizations in the world flourished in the region now known as Pakistan.
#     *   **Ancient Cities:** Home to ancient cities like Taxila and Mohenjo-daro, important centers of learning and trade in the past.
# *   **Geography & Landscapes:**
#     *   **Mountains:** Home to some of the world's highest mountain ranges, including the Himalayas, Karakoram, and Hindu Kush. K2, the second highest peak in the world, is located in Pakistan.
#     *   **Deserts:** The Thar Desert extends into Pakistan.
#     *   **Rivers:** The Indus River, the lifeline of Pakistan, flows through the country.
#     *   **Diverse Landscapes:** From fertile plains and lush valleys to rugged mountains and arid deserts, Pakistan boasts a diverse landscape.
# *   **Culture & Heritage:**
#     *   **Hospitality:** Known for its warm hospitality and welcoming people.
#     *   **Food:** Rich and flavorful cuisine, including biryani, kebabs, nihari, and various curries.
#     *   **Music:** A vibrant music scene with diverse genres, including Qawwali, folk music, and modern pop.
#     *   **Art & Architecture:** Mughal architecture, including the Lahore Fort and Badshahi Mosque, is a major attraction.
#     *   **Handicrafts:** Famous for its carpets, textiles, pottery, and woodwork.
# *   **Sports:**
#     *   **Cricket:** Cricket is the most popular sport in Pakistan, and the national team has won the Cricket World Cup.
#     *   **Hockey:** Pakistan has a rich history in field hockey, having won multiple Olympic gold medals.
# *   **Other:**
#     *   **Nuclear Power:** Pakistan is the only Muslim-majority country with nuclear weapons.
#     *   **Textile Industry:** A major producer and exporter of textiles.
#     *   **Diaspora:** A large and influential Pakistani diaspora around the world.
#
# It's worth noting that Pakistan, like any country, faces challenges as well. However, it's important to acknowledge its rich history, diverse culture, and the contributions of its people.
# Q:remeber my name is aroosa
# You remeber my name is aroosa
# AI: Okay, I will remember that your name is Aroosa.
# Q:quit
# --Message History--
# [SystemMessage(content='You are a helpful AI Assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='where is shibuya?', additional_kwargs={}, response_metadata={}), AIMessage(content="Shibuya is a special ward in **Tokyo, Japan**. It's known as one of Tokyo's most vibrant and trendy districts, famous for its iconic scramble crossing, fashion, nightlife, and youth culture.", additional_kwargs={}, response_metadata={}), HumanMessage(content='what is korea famous for?', additional_kwargs={}, response_metadata={}), AIMessage(content='Korea, both South and North, is famous for a variety of things. Here\'s a breakdown:\n\n**South Korea (Republic of Korea) is particularly known for:**\n\n*   **K-Pop & K-Drama:** Globally popular music and television dramas that have a massive international fanbase. Think BTS, Blackpink, Squid Game, and Crash Landing on You.\n*   **Technology:** Home to major tech companies like Samsung and LG, known for smartphones, electronics, and innovation.\n*   **Beauty & Skincare:** Korean beauty products (K-Beauty) are highly regarded for their quality and innovative ingredients.\n*   **Food:** Korean cuisine is beloved, especially Korean BBQ, kimchi, bibimbap, and street food.\n*   **Automobiles:** Hyundai and Kia are major car manufacturers.\n*   **Fashion:** Known for its trendy and unique fashion scene.\n*   **Cosmetics Surgery:** South Korea is a popular destination for cosmetic surgery.\n*   **History and Culture:** Rich history, including ancient palaces, temples, and traditions.\n*   **Taekwondo:** A Korean martial art that is also an Olympic sport.\n*   **Gaming:** A major player in the video game industry and esports.\n\n**North Korea (Democratic People\'s Republic of Korea) is mostly known for:**\n\n*   **Isolation:** One of the most isolated countries in the world, with limited access to outside information and strict government control.\n*   **Nuclear Program:** Its controversial nuclear weapons program.\n*   **Military:** A large and heavily militarized society.\n*   **Kim Dynasty:** Ruled by the Kim dynasty (Kim Il-sung, Kim Jong-il, and Kim Jong-un) since its founding.\n*   **Propaganda:** Heavily reliant on propaganda to maintain control and promote its ideology.\n*   **Human Rights Concerns:** Facing significant criticism for its human rights record.\n\nIt\'s important to remember that "Korea" is a peninsula with two distinct countries, each with its own unique characteristics and global standing.', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is pakistan famous for?', additional_kwargs={}, response_metadata={}), AIMessage(content="Pakistan is famous for a variety of things, including:\n\n*   **Historical Significance:**\n    *   **Indus Valley Civilization:** One of the oldest civilizations in the world flourished in the region now known as Pakistan.\n    *   **Ancient Cities:** Home to ancient cities like Taxila and Mohenjo-daro, important centers of learning and trade in the past.\n*   **Geography & Landscapes:**\n    *   **Mountains:** Home to some of the world's highest mountain ranges, including the Himalayas, Karakoram, and Hindu Kush. K2, the second highest peak in the world, is located in Pakistan.\n    *   **Deserts:** The Thar Desert extends into Pakistan.\n    *   **Rivers:** The Indus River, the lifeline of Pakistan, flows through the country.\n    *   **Diverse Landscapes:** From fertile plains and lush valleys to rugged mountains and arid deserts, Pakistan boasts a diverse landscape.\n*   **Culture & Heritage:**\n    *   **Hospitality:** Known for its warm hospitality and welcoming people.\n    *   **Food:** Rich and flavorful cuisine, including biryani, kebabs, nihari, and various curries.\n    *   **Music:** A vibrant music scene with diverse genres, including Qawwali, folk music, and modern pop.\n    *   **Art & Architecture:** Mughal architecture, including the Lahore Fort and Badshahi Mosque, is a major attraction.\n    * ...

# %% [markdown]
# # **Prompt Engineering**
# This notebook demonstrates various types of prompt engineering using Python and OpenAI API (or other LLMs)

# %%
from google.colab import userdata
import google.generativeai as genai

# %%
#Enter your API key as a secret (hidden input)
api_key=userdata.get('GOOGLE_API_KEY')

# %%
#configure Gemini
genai.configure(api_key=api_key)

# %%
#create model instance
model = genai.GenerativeModel("gemini-2.0-flash")

# %% [markdown]
# #**🔹Zero-Shot Prompting**

# %%
prompt = 'Translate the following to urde: Good Morning'

response = model.generate_content(prompt)

print(response.text)
# Out:
# The most common and appropriate translation of "Good Morning" to Urdu is:
#
# **صبح بخیر (Subah Bakhair)**
#
# This phrase literally means "May your morning be good" or "Good morning to you."

# %% [markdown]
# # **🔹 One-shot Prompting**

# %%
prompt = """
Translate English to urdu:
English: Hello → Urdu: ہیلو
English: Good night →
"""

response = model.generate_content(prompt)

# Output
print(response.text.strip())
# Out:
# Urdu: شب بخیر (Shab Bakhair)

# %% [markdown]
# # **🔹 Few-shot Prompting**

# %%
prompt = """
Translate English to urdu:
English: Hello → ہیلو
English: Good night → شب بخیر
English: Thank you →
"""

response = model.generate_content(prompt)

# Output result
print(response.text.strip())
# Out:
# Thank you → شکریہ (Shukriya)

# %% [markdown]
# # **🔹 Chain-of-Thought Prompting**

# %%
prompt = """
Q: If there are 5 apples and you eat 2, how many are left?
A: Let's think step-by-step.
"""

response = model.generate_content(prompt)

# Print the response
print(response.text.strip())
# Out:
# A: There are 3 apples left.

# %% [markdown]
# # **🔹 Role-based Prompting**

# %%
prompt = "You are a helpful doctor. Suggest home remedies for common cold."

response = model.generate_content(prompt)

# Print the output
print(response.text.strip())
# Out:
# Alright, I understand you're looking for some home remedies to help ease the symptoms of a common cold.  It's important to remember that while these remedies can help you feel better, they won't *cure* the cold.  The common cold is a viral infection, and your body needs time to fight it off. These remedies are aimed at alleviating the discomfort.
#
# **Here are some general recommendations and specific remedies, keeping in mind that individual results may vary:**
#
# **1.  Hydration is Key!**
#
# *   **Why:**  Staying hydrated is crucial.  It helps thin mucus, making it easier to cough up or blow your nose.  It also prevents dehydration, which can worsen symptoms like headache and fatigue.
# *   **What to do:**  Drink plenty of fluids throughout the day.  Good choices include:
#     *   **Water:**  The most basic and essential.
#     *   **Clear Broth (Chicken or Vegetable):** Provides electrolytes and is soothing.
#     *   **Herbal Teas:**  Chamomile, ginger, and lemon teas are good options.  Be mindful of caffeine in some teas (like black tea).
#     *   **Diluted Fruit Juice:** Avoid sugary drinks as they can sometimes worsen congestion.
#     *   **Electrolyte Drinks (e.g., Pedialyte, diluted sports drinks):**  Especially helpful if you're experiencing diarrhea or vomiting along with your cold.
# *   **Avoid:** Sugary drinks, alcohol, and excessive caffeine, as these can dehydrate you.
#
# **2. Rest and Relaxation**
#
# *   **Why:** Your body needs energy to fight off the virus.  Rest allows it to focus its resources on healing.
# *   **What to do:**
#     *   **Get Enough Sleep:** Aim for 7-9 hours of sleep per night.
#     *   **Avoid Strenuous Activity:**  Give your body a break from exercise and other demanding tasks.
#     *   **Relax:**  Read a book, watch a movie, or listen to calming music.
#
# **3. Symptom-Specific Remedies**
#
# *   **Sore Throat:**
#     *   **Gargling with Salt Water:**  Mix 1/4 to 1/2 teaspoon of salt in 8 ounces of warm water. Gargle for 30 seconds several times a day.  This helps reduce inflammation and soothe the throat. **Important: Do not swallow!**
#     *   **Honey:** A natural cough suppressant and soother.  Take a spoonful of honey (especially Manuka honey) or add it to warm tea.  **Caution:  Do not give honey to children under 1 year old due to the risk of botulism.**
#     *   **Lozenges:**  Over-the-counter lozenges can provide temporary relief. Look for ones with menthol or benzocaine for a numbing effect.
#     *   **Warm liquids with lemon and honey:** These can be very soothing and help break up mucus.
#
# *   **Congestion (Nasal Congestion and Sinus Pressure):**
#     *   **Steam Inhalation:**  Take a hot shower, use a humidifier, or try steam inhalation.  To do this, carefully pour hot (but not boiling) water into a bowl, cover your head with a towel, and lean over the bowl (about 12 inches away) to inhale the steam.  Be careful not to burn yourself.  You can add a few drops of eucalyptus or peppermint oil for extra relief.
#     *   **Saline Nasal Spray:**  Helps to moisten nasal passages and loosen mucus. Use as directed on the package.
#     *   **Neti Pot/Nasal Rinse:**  Use a neti pot or nasal rinse to flush out nasal passages with saline solution.  **Important: Use distilled or sterile water to avoid infection. Follow the instructions carefully.**
#     *   **Warm Compress:** Apply a warm, damp cloth to your face over your sinuses to help relieve pressure.
#
# *   **Cough:**
#     *   **Honey:** As mentioned above, honey is a natural cough suppressant (for adults and children over 1 year old).
#     *   **Humidifier:**  Keeps the air moist, which can help soothe a dry cough.
#     *   **Elevate Your Head:**  Use extra pillows to prop yourself up while sleeping.  This can help reduce coughing at night.
#
# **4. Foods to Support Your Immune System**
#
# *   While no food will *cure* a cold, certain foods can help support your immune system.
#     *   **Vitamin C-Rich Foods:** Citrus fruits (oranges, lemons, grapefruits), berries, and bell peppers.
#     *   **Garlic:** Contains compounds with antiviral and antibacterial properties.
#     *   **Ginger:** Has anti-inflammatory properties and can help soothe a sore throat.
#     *   **Yogurt with Probiotics:**  Probiotics can help support gut health, which is important for immune function.
#
# **Important Considerations and When to See a Doctor:**
#
# *   **These remedies are for the *common cold* only.**  If you suspect you have the flu, pneumonia, or another more serious illness, see a doctor.
# *   **Seek medical attention if you experience any of the following:**
#     *   High fever (over 103°F or 39.4°C)
#     *   Difficulty breathing or shortness of breath
#     *   Chest pain
#     *   Severe headache or stiff neck
#     *   Persistent cough that lasts for more than a few weeks
#     *   Dehydration (decreased urination, dizziness)
#     *   Symptoms that worsen or don't improve after 7-10 days
#
# *   **Children and the Elderly:**  Be extra cautious with home remedies for children and the elderly.  Consult a doctor before trying anything new.  **Never give honey to infants under 1 year old.**
# *   **Pregnancy and Breastfeeding:**  Many over-the-counter medications are not safe during pregnancy or breastfeeding.  Consult your doctor before taking any medications or trying new home remedies.
# *   **Drug Interactions:** If you are taking any medications, talk to your doctor or pharmacist to make sure there are no interactions with any home remedies you are considering.
# *   **Listen to Your Body:** If a remedy doesn't seem to be helping or is making you feel worse, stop using it.
#
# **Disclaimer:** This information is for general knowledge and informational purposes only, and does not constitute medical advice. It is essential to consult with a qualified healthcare professional for any health concerns or before making any decisions related to your health or treatment.
#
# I hope these suggestions help you feel better! Remember to rest, stay hydrated, and listen to your body.  Take care!

# %% [markdown]
# #**🔹 Instruction-based Prompting**

# %%
prompt = """
Summarize the following in 3 bullet points:
Artificial Intelligence is transforming industries. It automates tasks, provides insights, and enhances decision-making.
"""

response = model.generate_content(prompt)

# Output result
print(response.text.strip())
# Out:
# Here's a summary in 3 bullet points:
#
# *   **Automation:** AI automates repetitive and mundane tasks across various industries.
# *   **Insights:** AI provides valuable insights by analyzing large datasets, revealing patterns and trends.
# *   **Improved Decision-Making:** AI-driven analysis empowers better and more informed decision-making processes.

# %% [markdown]
# # **🔹 ReACT Prompting (Simulated)**

# %%
prompt = """
You are an intelligent agent. Follow the format of Thought, Action, and Observation.

Task: What is the weather in Lahore?

Thought: I need to find the weather.
Action: Search['Weather in Lahore']
Observation: It's 35°C and sunny in Lahore.
Answer: It's currently 35°C and sunny in Lahore.
"""
response = model.generate_content(prompt)

# Output result
print(response.text.strip())
# Out:
# Thought: I have already found the answer in the previous turn. I can just repeat the information.
# Action: None
# Observation: None
# Answer: It's currently 35°C and sunny in Lahore.

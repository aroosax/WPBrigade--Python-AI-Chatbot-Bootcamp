# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
! pip install langchain-google-genai

# %%
#importing libraries
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from google.colab import userdata

# %%
api_key = userdata.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash",
    google_api_key = api_key
)

# %%
#creating message and getting a response
message = [
    SystemMessage("You are a professional career coach specializing in interview preparation"),
    HumanMessage("Share one quick tip to handle tough interview questions with confidence!")
]
response = llm.invoke(message)
print(response.content)
# Out:
# Okay, here's one quick tip to handle tough interview questions with confidence:
#
# **Use the "Pause, Rephrase, and Answer" Technique.**
#
# *   **Pause:** Take a brief moment (2-3 seconds) to collect your thoughts. This shows you're thoughtful, not stumped.
# *   **Rephrase:** Rephrase the question in your own words. This buys you more time and ensures you understand the question correctly. For example, "So, if I understand correctly, you're asking about a time when I faced a significant challenge at work and how I overcame it?"
# *   **Answer:** Now, deliver your concise and relevant answer.
#
# **Why this works:**
#
# *   **Reduces Panic:** The pause prevents you from blurting out the first thing that comes to mind.
# *   **Clarifies Understanding:** Rephrasing confirms you're addressing the core issue.
# *   **Builds Confidence:** It demonstrates composure and control, even when faced with a challenging question.
#
# Good luck with your interview!
